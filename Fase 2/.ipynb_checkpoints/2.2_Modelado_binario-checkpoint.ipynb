# %% [markdown]
# <!--Header-->
# <div style="background-color: #fff; color: black">
#     <div style="padding-bottom: 20px; display: flex; justify-content: space-between; align-items: flex-start;">
#         <div style="width: 60%;">
#             <h1 style="margin: 16px">TFG - Inteligencia Artificial</h1>
#             <p style="margin: 16px; padding-bottom: 0">Junio de 2025</p>
#         </div>
#         <div style="width: 40%; text-align: right">
#             <img src="https://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg" alt="Logo UOC">
#         </div>
#     </div>
#     <h2 style="text-align: justify; padding: 0 16px">Aplicación de técnicas de IA fiable en la predicción del índice de calidad de vida en personas con tratamiento oncológico mediante aprendizaje automático.</h2>
#     <div style="background-color: #000; width: 100%; height: 2px; margin: 24px 0"></div>
#     <div style="padding: 20px">
#         <h4 style="margin: 0 0; padding: 0 0">Pablo Pimàs Verge</h4>
#         <h5 style="margin: 0 0; padding: 0 0">Grado en Ingeniería Informática</h5>
#         <h5 style="margin: 0 0 4px; padding: 0 0">Inteligencia Artificial</h5>
#         <h4 style="margin: 8px 0 4px; padding: 0 0">Dra. María Moreno de Castro</h4>
#         <h4 style="margin: 0 0; padding: 0 0">Dr. Friman Sanchéz</h4>
#     </div>
# </div>
#
# <!--/Header-->

# %% [markdown]
# # Fase 2
# #### Segunda Parte
# ##### - Entrenamiento de modelos
# ##### - Aplicación del modelo óptimo
#
# # Modelado - Clasificación supervisada binaria
#
# En esta fase el problema se plantea como una clasificación binaria del índice de calidad de vida (QoL) en personas con tratamiento oncológico. En la preparación de los datos [1], se ha transformado la variable QoL en binaria donde: la clase 0 representa un nivel de calidad de vida aceptable y la clase 1 representa un nivel de mejorable.
#
# Este cuaderno corresponde a la segunda iteración del modelado dentro de la fase 2 del plan de trabajo del TFG. Se aborda el entrenamiento y la aplicación de los modelos para la clasificación binaria del QoL. En consecuencia, se abordará la optimización de los resultados mediante la predicción probabilística y el posterior ajuste del umbral de decisión, utilizando el conjunto de validación.
#
#
# ### Objetivos
#
# En el presente cuaderno se realizarán las siguientes acciones:
#
# - Separar los datos de df_C30_C23_2 en los conjuntos de: entrenamiento, prueba, validación y calibración
# - Entrenar y aplicar los siguientes modelos:
#     - Decision tree
#     - Random Forest
#     - XGBoost
#     - CatBoost
#     - LGBMachine
# - Seleccionar el modelo óptimo
#
# ### Índice
#
# 1. Creación de los conjuntos de datos
# 2. Entrenamiento y clasificación
# 3. Conclusiones
# 4. Exportación del modelo seleccionado
# 5. Bibliografía

# %% [markdown]
# ### Importaciones

# %%
# Importaciones de librerías básicas
import joblib
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# Importaciones de Scikit-learn para preparación de datos, evaluación de modelos y optimización de parámetros
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, recall_score, f1_score

# Importaciones de Modelos
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

# Funciones auxiliares
import xaiuq_functions as afn

# %%
# Configuraciones
# %matplotlib inline
warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.2f}'.format
plt.rc('font', size=10)
plt.rcParams["legend.frameon"] = False
sns.set_theme(
    style="white",
    palette="viridis",
    rc={
        "axes.spines.left": False,
        "axes.spines.bottom": False,
        "axes.spines.right": False,
        "axes.spines.top": False
    }
)
sns.set_style("white", {"axes.grid": False})

# %% [markdown]
# ### Carga de los datos

# %%
# Carga de los datos en un dataframe de Pandas a partir del conjunto generado en la fase previa en formato csv
file_path = "./data/QLQ_C30_C23_2.csv"
df = pd.read_csv(file_path)
# Filas duplicadas
print('Total de observaciones sin duplicados: ', df.duplicated().count())
# Out:
# Total de observaciones sin duplicados:  1474

# %%
# Comprobamos que el conjunto importado contiene las 1474 observaciones sin valores faltantes y las 21 variables de tipo decimal (float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1474 entries, 0 to 1473
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Physical functioning           1474 non-null   float64
#  1   Role functioning               1474 non-null   float64
#  2   Emotional functioning          1474 non-null   float64
#  3   Cognitive functioning          1474 non-null   float64
#  4   Social functioning             1474 non-null   float64
#  5   Fatigue                        1474 non-null   float64
#  6   Nausea and vomiting            1474 non-null   float64
#  7   Pain                           1474 non-null   float64
#  8   Dyspnea                        1474 non-null   float64
#  9   Insomnia                       1474 non-null   float64
#  10  Appetite loss                  1474 non-null   float64
#  11  Constipation                   1474 non-null   float64
# ...

# %% [markdown]
# ## 1. Creación de los conjuntos de entrenamiento, prueba validación y calibración
#
# Para la división de los conjuntos de entrenamiento y prueba aplicaremos una proporción de 60-40 con estratificación para asegurar que las clases de la variable objetivo se distribuyan uniformemente en todos los conjuntos.
# Por un lado, con el fin de cuantificar la incertidumbre del modelo en la próxima etapa, es necesario reservar un subconjunto de los datos. Para ello, separamos un 10% del conjunto de prueba, ya que el modelo no debe conocerlos durante el entrenamiento.
# Por otro lado, del conjunto de prueba necesitamos separar un subconjunto para la optimización del umbral de decisión. Este conjunto de validación será del 10% del total y el 20% restante lo utilizaremos para la prueba definitiva del modelo que se comporte mejor.
# De esta manera, la división será de 60-20-10-10 para entrenamiento, prueba, validación y calibración respectivamente.

# %%
# Extracción de las variables independientes en un dataframe y de la variable dependiente en una serie
X = df.drop('QoL', axis=1)
y = df['QoL']
# Apartamos el 60% para entrenamiento
X_train, X_rest, y_train, y_rest = train_test_split(X, y, test_size=0.40, stratify=y, random_state=73)
# Del 40% restante, separamos 20% para test, 10% para validación y el 10% restante para calibración
X_test, X_temp, y_test, y_temp = train_test_split(X_rest, y_rest, test_size=0.50, stratify=y_rest, random_state=73)
X_cal, X_val, y_cal, y_val = train_test_split(X_temp, y_temp, test_size=0.50, stratify=y_temp, random_state=73)

# %% [markdown]
# Una vez dispuestos todos los conjuntos necesarios, mediante la función auxiliar viz_split_distributions realizaremos una comprobación de la distribución de las clases en cada uno de ellos.

# %%
# Visualizamos las proporciones de las clases de QoL en todos los conjuntos
afn.viz_split_distributions([df['QoL'], y_train, y_val, y_test, y_cal], ['QLQ_C30_C23', 'Train', 'Validation', 'Test', 'Calibration'], 'QoL')

# %% [markdown]
# Podemos ver que la distribución de la variable objetivo tiene una variación inferior al 1% para cada clase en todos los conjuntos generados. Además, las 1474 observaciones del conjunto original se han separado en: 884 para entrenamiento, 148 para la validación, 295 para el test y 147 para la calibración. Todos los conjuntos presentan un balanceo de clases muy cercano a una proporción de 50-50.

# %%
# Guardamos los conjuntos en una lista para ser usada en las funciones auxiliares
datasets = [X_train, y_train]
labels = ['Aceptable', 'Mejorable']

# %% [markdown]
# ## 2. Entrenamiento y Clasificación
#
# La estrategia y metodología a seguir son las mismas que en la primera iteración del modelado, documentada en el cuaderno Modelado - Clasificación supervisada multiclase [2].
#
# ***- Entrenamiento***
#
# Se entrena cada modelo con el conjunto de entrenamiento utilizando la técnica de validación cruzada k-fold con k = 5, integrada en el proceso de optimización de hiperparámetros mediante GridSearchCV, tal como se llevó a cabo en la clasificación multiclase (ver referencia [2] para más detalles).
#
# ***- Métrica***
#
# A diferencia del enfoque multiclase, esta iteración binaria incorpora una etapa adicional de optimización del umbral de decisión. En lugar de mantener el umbral por defecto (0.5), se analiza el comportamiento del modelo en función de diferentes métricas —principalmente recall y f1-score macro— para determinar un punto de equilibrio con relevancia clínica.
#
# Durante la búsqueda de hiperparámetros, el ajuste por F1 score maximiza la sensibilidad hacia la clase de interés (QoL mejorable), reduciendo los falsos negativos de forma significativa, ya que el conjunto de datos se encuentra muy balanceado. En la búsqueda del umbral de decisión óptimo, se observó que el uso de f1-score binario consigue un mejor compromiso entre la correcta detección de casos y la contención de falsos positivos.
#
# ***-Umbral de decisión***
#
# ***- Clasificación***
#
# Una vez identificado el mejor modelo (estimator) mediante la combinación óptima de hiperparámetros y umbral de decisión, se realiza la predicción sobre el conjunto de prueba. Los resultados se comparan con los del conjunto de validación para detectar posibles síntomas de sobreajuste y evaluar la calidad final de la clasificación.
#
# Para la clasificación se entrenarán los siguientes modelos:
#
# - Decision Tree
# - Random Forest
# - XGBoost
# - CatBoost
# - LightGBM

# %% [markdown]
# ### 2.1 Decision Tree
#
# Para mayor información sobre este y los modelos siguientes se puede consultar el cuaderno de clasificación multiclase [2].

# %%
# Instanciamos el modelo 
decision_tree =  DecisionTreeClassifier(random_state=73)
# Establecemos un diccionario con los valores de los parámetros que tomará el modelo en el entrenamiento
dt_parameters = {
    # Criterios para medir la ganancia de información (calidad de la división)
    'criterion': ['gini', 'entropy'],
    # Estrategias de división
    'splitter': ['best', 'random'],
    # Máxima profundidades del árbol (None permite la profundidad máxima posible)
    'max_depth': [7, 8, 9],
    # Mínimo de casos para dividir un nodo
    'min_samples_split': [3, 5, 7],
    # Mínimo de casos en las hojas
    'min_samples_leaf': [8, 9, 10],
    # Factor de poda
    'ccp_alpha': [0.002, 0.003, 0.004],
}
# Creamos la grilla de búsqueda de parámetros
dt_grid = GridSearchCV(
    estimator=decision_tree, 
    param_grid=dt_parameters, 
    verbose=1,
    scoring='f1_macro',
    cv=5,
    n_jobs=-1
)
# Entrenamos los modelos generados por la grilla
# %time dt_grid.fit(X_train, y_train)
# Visualización de los resultados
print('Media de F1 score: %.3f' % dt_grid.best_score_)
print('Desviación estándar: ', dt_grid.cv_results_['std_test_score'][dt_grid.best_index_].round(3))
print('Parámetros que producen el mejor clasificador: ')
print('Criterio: ', dt_grid.best_params_['criterion'])
print('Estrategia: ', dt_grid.best_params_['splitter'])
print('Profundidad máxima: ', dt_grid.best_params_['max_depth'])
print('Mínimo de muestras por división: ', dt_grid.best_params_['min_samples_split'])
print('Mínimo de muestras por hoja: ', dt_grid.best_params_['min_samples_leaf'])
print('Factor de poda: ', dt_grid.best_params_['ccp_alpha'])
print('Cantidad de nodos: ', dt_grid.best_estimator_.tree_.node_count)
print('Cantidad de hojas: ', dt_grid.best_estimator_.tree_.n_leaves)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# CPU times: user 384 ms, sys: 109 ms, total: 493 ms
# Wall time: 3.57 s
# Media de F1 score: 0.767
# Desviación estándar:  0.033
# Parámetros que producen el mejor clasificador:
# Criterio:  entropy
# Estrategia:  random
# Profundidad máxima:  8
# Mínimo de muestras por división:  3
# Mínimo de muestras por hoja:  9
# Factor de poda:  0.003
# Cantidad de nodos:  47
# Cantidad de hojas:  24

# %% [markdown]
# Este modelo alcanzó una media de F1-score de 0.767, con una desviación estándar de 0.033 en las cinco particiones de la validación cruzada. Estos valores indican un buen rendimiento general y una estabilidad razonable entre pliegues, lo que sugiere una buena capacidad de generalización.
#
# El uso del criterio entropy implica que el modelo prioriza divisiones que maximizan la ganancia de información, mientras que la estrategia de división random introduce cierta aleatoriedad en la selección de características candidatas, lo que puede ayudar a evitar sobreajuste en árboles profundos. La poda suave aplicada con un factor de 0.003 también contribuye a controlar la complejidad del modelo y a mejorar su capacidad de generalización.
#
# Entrenamos el mejor modelo con el conjunto completo de los datos de entrenamiento (sin validación cruzada) y generamos las predicciones probabilisticas del conjunto de validación. Luego, nos valemos de la función auxiliar viz_classification_reports que se encargará de mostrar el reporte de las métricas y graficar la comparativa de entre ambos conjuntos.

# %%
# Entrenamos el modelo con los mejores hiperparámetros
dt_model = dt_grid.best_estimator_
dt_model.fit(X_train, y_train)
# Obtenemos las probabilidades de cada clase para las predicciones en el conjunto de validación y mostramos los resultados
y_pred_dt = dt_model.predict_proba(X_val)
y_pred_train_dt, y_pred_val_dt, dt_report = afn.viz_classification_reports(dt_model, X_train, y_train, X_val, y_val)
# Out:
# Reporte sobre el conjunto de ENTRENAMIENTO:
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.84      0.80       422
#          1.0       0.84      0.77      0.80       462
#
#     accuracy                           0.80       884
#    macro avg       0.80      0.80      0.80       884
# weighted avg       0.81      0.80      0.80       884
#
# Reporte sobre el conjunto de validation:  VALIDATION
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.77      0.75        71
#          1.0       0.78      0.74      0.76        77
#
#     accuracy                           0.76       148
#    macro avg       0.76      0.76      0.76       148
# weighted avg       0.76      0.76      0.76       148

# %% [markdown]
# El modelo entrenado con los hiperparámetros óptimos mostró un buen rendimiento en el conjunto de entrenamiento, con un accuracy del 80%, un f1-score macro de 0.80 y una notable capacidad para identificar correctamente la clase de interés (QoL mejorable), alcanzando un recall del 0.77 para la clase positiva.
#
# En el conjunto de validación, como es esperable, las métricas disminuyen ligeramente. La precisión general se mantiene en torno al 76%, y el f1-score para la clase mejorable (1.0) sigue siendo relativamente bueno (0.76), lo cual confirma la solidez del modelo. Sin embargo, la clase aceptable (0.0) muestra una mayor caída, especialmente en recall, que desciende del 80% en entrenamiento al 77% en validación.
#
# Los gráficos comparativos permiten observar con claridad esta diferencia: el rendimiento del modelo es consistentemente ambas clases, con menos variación entre conjuntos, mientras que en la clase 1 se detecta una pérdida menos acusada de capacidad predictiva.
#
# Este patrón es clínicamente aceptable dentro del objetivo del sistema, que prioriza identificar correctamente a los pacientes con calidad de vida mejorable, aunque implique una menor precisión en la clase complementaria. En conjunto, el modelo mantiene un equilibrio razonable entre sensibilidad y precisión, con un desempeño robusto y sin signos evidentes de sobreajuste.

# %% [markdown]
# A continuación, se incorpora el estudio del umbral de decisión para optimizar la clasificación. Para ello, se utiliza una función auxiliar que grafica la evolución de distintas métricas —precision, recall, accuracy y f1-score— conforme se incrementa el umbral. El umbral óptimo se define como aquel que maximiza una métrica concreta (en nuestro caso, f1-score), permitiendo encontrar un equilibrio entre sensibilidad y precisión que se ajuste al objetivo clínico del modelo. El gráfico se complementa con el valor de la curva ROC, que ofrece una visión global del poder discriminativo del modelo independientemente del umbral seleccionado.

# %%
# Calculamos los umbrales y los visualizamos
dt_best_threshold, dt_metrics = afn.viz_threshold_behavior(dt_model, X_val, y_val, num_thresholds=30, metric=f1_score)
# Extraemos las probabilidades de la clase mejorable de las predicciones del modelo
probs_dt = y_pred_dt[:, 1]
# Seleccionamos aquellas que satisfacen el umbral óptimo encontrado
y_pred_proba_dt = (probs_dt >= dt_best_threshold)
# Guardamos las métricas para realizar la comparación con los otros modelos
dt_metrics['model'] = 'Decision Tree'

# %%
# Analizamos el reporte con el umbral ajustado
print("Reporte con umbral ajustado:")
print(classification_report(y_val, y_pred_proba_dt, target_names=labels))
# Out:
# Reporte con umbral ajustado:
#               precision    recall  f1-score   support
#
#    Aceptable       0.79      0.69      0.74        71
#    Mejorable       0.74      0.83      0.79        77
#
#     accuracy                           0.76       148
#    macro avg       0.77      0.76      0.76       148
# weighted avg       0.77      0.76      0.76       148

# %% [markdown]
# El ajuste del umbral de decisión mediante la optimización del f1-score permitió alcanzar un equilibrio entre la sensibilidad y la precisión del modelo. El umbral óptimo se identificó en 0.402, valor que maximiza el rendimiento global del clasificador manteniendo la utilidad clínica.
#
# Con este umbral, el modelo alcanza un f1 score de 0.79 con una sensibilidad del 83% para la clase mejorable y una precisión del 74%, lo que indica una buena capacidad para detectar correctamente los casos relevantes, aunque genera un exceso de falsos positivos. Al mismo tiempo, la clase QoL aceptable logra una precisión del 79%, aunque su recall disminuye a 69%, un efecto esperado al desplazar el umbral hacia la clase positiva.
#
# Observamos la matriz de confusión para visualizar mejor el cambio que produce el ajuste del umbral.

# %%
afn.viz_confusion_matrix_thres(labels, y_val, y_pred_val_dt, y_pred_proba_dt)

# %% [markdown]
# La matriz de confusión confirma la mejora sustancial en la capacidad del modelo para identificar correctamente los casos de calidad de vida mejorable tras ajustar el umbral de decisión. El número de verdaderos positivos aumenta considerablemente, pasando de 57 a 64, mientras que los falsos negativos se reducen casi a la mitad, de 20 a 13. Esto implica una mayor sensibilidad hacia la clase clínicamente relevante, lo cual es fundamental para el objetivo del sistema.
#
# Este ajuste se logra con un coste moderado: se observa un incremento en los falsos positivos (de 16 a 22) y una ligera reducción en la correcta clasificación de la clase aceptable (de 55 a 49), aunque esta pérdida no es significativa si se compara con la mejora global obtenida en la clase de interés. En conjunto, el modelo ajustado ofrece un rendimiento más equilibrado y alineado con el propósito clínico del sistema, priorizando la identificación de los casos con potencial de intervención sin comprometer excesivamente la precisión.

# %% [markdown]
# ## 2.3 Random Forest

# %%
# Instanciamos el modelo
rf_model = RandomForestClassifier(
    random_state = 73,
    n_jobs=-1
)
# Definimos el diccionario de parámetros
rf_parameters = {
    'criterion': ['gini', 'entropy'],
    # Número de árboles en cada modelo
    'n_estimators': [100, 150, 200],
    'max_depth': [12, 14, 16],
    'min_samples_split': [3, 4, 5],
    'min_samples_leaf': [4, 6, 8],
    'ccp_alpha': [0.004, 0.005, 0.006]
}
# Instanciamos la grilla de búsqueda
rf_grid = GridSearchCV(
    estimator=rf_model,
    param_grid=rf_parameters,
    scoring='f1_macro',
    verbose=True,
    cv=5,
    n_jobs=-1
)
# Realizamos el entrenamiento
# %time rf_grid.fit(X_train, y_train)
# Finalmente, visualizamos los resultados
print('Media de F1 score: %.3f' % rf_grid.best_score_)
print('Desviación estándar: ', rf_grid.cv_results_['std_test_score'][rf_grid.best_index_].round(3))
print('Parámetros que producen el clasificador óptimo: ')
print('Criterio: ', rf_grid.best_params_['criterion'])
print('Profundidad máxima: ', rf_grid.best_params_['max_depth'])
print('Mínimo de muestras por división: ', rf_grid.best_params_['min_samples_split'])
print('Mínimo de muestras por hoja: ', rf_grid.best_params_['min_samples_leaf'])
print('Factor de poda: ', rf_grid.best_params_['ccp_alpha'])
print('Cantidad de árboles: ', rf_grid.best_params_['n_estimators'])
print('Cantidad de nodos del primer árbol: ', rf_grid.best_estimator_.estimators_[0].tree_.node_count)
print('Cantidad de hojas del primer árbol: ', rf_grid.best_estimator_.estimators_[0].tree_.n_leaves)
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# CPU times: user 2.78 s, sys: 568 ms, total: 3.34 s
# Wall time: 1min 24s
# Media de F1 score: 0.802
# Desviación estándar:  0.023
# Parámetros que producen el clasificador óptimo:
# Criterio:  entropy
# Profundidad máxima:  14
# Mínimo de muestras por división:  3
# Mínimo de muestras por hoja:  4
# Factor de poda:  0.004
# Cantidad de árboles:  100
# Cantidad de nodos del primer árbol:  75
# Cantidad de hojas del primer árbol:  38

# %% [markdown]
# El modelo encontrado alcanza un F1 score de 0.802, muy lijeramente superior al modelo anterior, con desviación estándar de 0.023 que indica una estabilidad en todas las hojas de la validación cruzada. Tiene una complejidad relativamente simple con 100 árboles y una profundidad máxima de 14 niveles. Se le ha aplicado un factor alpha muy suave de 0.004 que reduce la complejidad y mejora el sobreajuste. Si observamos el primer árbol del bosque, encontramos que está formado por 75 nodos y 38 hojas.
#
# Continuamos con el entranamiento y la obtención de las probabilidades del mejor *estimator*

# %%
# Continuamos con los mismos pasos que en el modelo anterior
rf_model = rf_grid.best_estimator_
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict_proba(X_val)
y_pred_train_rf, y_pred_val_rf, rf_report = afn.viz_classification_reports(rf_model, X_train, y_train, X_val, y_val)
# Out:
# Reporte sobre el conjunto de ENTRENAMIENTO:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.90      0.87       422
#          1.0       0.90      0.84      0.87       462
#
#     accuracy                           0.87       884
#    macro avg       0.87      0.87      0.87       884
# weighted avg       0.87      0.87      0.87       884
#
# Reporte sobre el conjunto de validation:  VALIDATION
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.82      0.80        71
#          1.0       0.82      0.79      0.81        77
#
#     accuracy                           0.80       148
#    macro avg       0.80      0.80      0.80       148
# weighted avg       0.80      0.80      0.80       148

# %% [markdown]
# El modelo de ensamble representa una mejoría sustancial con respecto al árbol único. Por un lado, la precisión ha aumentado considerablemente para ambas clases y junto con la exactitud global han subido un 5%. Al observar el recall encontramos que la mejoría se ha producido ambas clases de forma uniforme, es decir, el modelo ha podido diferenciar mucho mejor las clases y ha recortado tanto los falsos positivos como los falsos negativos. Los gráficos nos muestran como las caídas en las métricas no muestran una gran diferencia entre ambos conjuntos confirmando que no existe un sobreajuste preocupante.
#
# Continuamos con la búsqueda del umbral óptimo como anteriormente.

# %%
# Aplicamos el mismo flujo que en el caso anterior
rf_best_threshold, rf_metrics = afn.viz_threshold_behavior(rf_model, X_val, y_val, num_thresholds=25)
probs_rf = y_pred_rf[:, 1]
y_pred_proba_rf = (probs_rf >= rf_best_threshold)
rf_metrics['model'] = 'Random Forest'

# %%
print("Reporte con umbral ajustado:")
print(classification_report(y_val, y_pred_proba_rf, target_names=labels))
# Out:
# Reporte con umbral ajustado:
#               precision    recall  f1-score   support
#
#    Aceptable       0.81      0.79      0.80        71
#    Mejorable       0.81      0.83      0.82        77
#
#     accuracy                           0.81       148
#    macro avg       0.81      0.81      0.81       148
# weighted avg       0.81      0.81      0.81       148

# %% [markdown]
# En este caso, podemos ver que el umbral ajustado no mejora tan significativamente la clasificación como en el caso anterior. Tenemos una muy leve mejoría en el f1 score de la clase 1 junto con una disminución del recall que nos indica un leve aumento de los falsos positivos. En todo caso, los cambios son mínimos indicando un posible límite en la diferenciación de las características de las clases.

# %%
# Graficamos la matriz de confusión antes y después del ajuste
afn.viz_confusion_matrix_thres(labels, y_val, y_pred_val_rf, y_pred_proba_rf)

# %% [markdown]
# Como hemos mencionado anteriormente, el ajuste del umbral reduce los falsos negativos mejorando la clasificación de la clase 1, a costa de un aumento de los falsos positivos. Estos casos «limítrofes» son muy difíciles de diferenciar. Esta idea puede visualizarse claramente en el siguiente gráfico de dispersión que representa los casos clasificados correctamente e incorrectamente respecto al umbral de decisión. Como se muestra, existe una zona intermedia donde se concentran los errores, lo que pone en evidencia la dificultad de clasificar los casos limítrofes incluso tras el ajuste óptimo del umbral.

# %%
afn.viz_threshold_optimization(probs_rf, y_val, y_pred_proba_rf, rf_best_threshold)

# %% [markdown]
# El gráfico evidencia como el umbral fija la clasificación en el punto donde conseguir un nuevo verdadero positivo alcanzando el cuadrado rojo (falso negativo), significa aumentar los falsos positivos: convertir los círculos azules (verdaderos negativos) en cruces naranjas. Las dispersiones de las probabilidades en ambas clases hacen que no sea posible una diferenciación más eficaz con este modelo.

# %% [markdown]
# ### 2.3 XGBoost

# %%
# Realizamos el mismo flujo de trabajo que en los modelos anteriores
xg_parameters = {
    'eta': [0.01, 0.02, 0.03],
    'max_depth': [12, 14],
    'min_child_weight': [3, 4, 5],
    'n_estimators': [150, 175, 200],
    'subsample': [0.5, 1.0]
}
xg_model = XGBClassifier(
    objective='binary:logistic',               
    eval_metric='logloss',     
    random_state=73,
)
xg_grid = GridSearchCV(
    estimator=xg_model,
    param_grid=xg_parameters,
    scoring='recall',
    cv=5,
    verbose=True,
    n_jobs=-1
)
# %time xg_grid.fit(X_train, y_train)
print('Media de F1 score: %.3f' % xg_grid.best_score_)
print('Desviación estándar: ', xg_grid.cv_results_['std_test_score'][xg_grid.best_index_].round(3))
print('Parámetros que producen el clasificador óptimo: ')
print('Tasa de aprendizaje: ', xg_grid.best_params_['eta'])
print('Profundidad máxima: ', xg_grid.best_params_['max_depth'])
print('Mínimo peso de división: ', xg_grid.best_params_['min_child_weight'])
print('Número de árboles: ', xg_grid.best_params_['n_estimators'])
print('Subsample: ', xg_grid.best_params_['subsample'])
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# CPU times: user 1.25 s, sys: 244 ms, total: 1.5 s
# Wall time: 2.98 s
# Media de F1 score: 0.816
# Desviación estándar:  0.05
# Parámetros que producen el clasificador óptimo:
# Tasa de aprendizaje:  0.02
# Profundidad máxima:  12
# Mínimo peso de división:  3
# Número de árboles:  175
# Subsample:  0.5

# %% [markdown]
# El modelo encontrado obtiene una muy leve mejoría en el valor de F1 macro con respecto a los anteriores. La cantidad de estimadores es mayor que en el caso del random forest, aunque no llega a duplicarla y presenta una profundidad 2 niveles menor. En cuanto al subsample, podemos ver que la división se produce con el 50% de las variables, lo que reduce el riesgo de sobreajuste.

# %%
# Continuamos con el análisis del mejor modelo encontrado
xg_model = xg_grid.best_estimator_
xg_model.fit(X_train, y_train)
y_pred_xg = xg_model.predict_proba(X_val)
y_pred_train_xg, y_pred_val_xg, xg_report= afn.viz_classification_reports(xg_model, X_train, y_train, X_val, y_val)
# Out:
# Reporte sobre el conjunto de ENTRENAMIENTO:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.87      0.86       422
#          1.0       0.88      0.85      0.87       462
#
#     accuracy                           0.86       884
#    macro avg       0.86      0.86      0.86       884
# weighted avg       0.86      0.86      0.86       884
#
# Reporte sobre el conjunto de validation:  VALIDATION
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.80      0.80        71
#          1.0       0.82      0.81      0.81        77
#
#     accuracy                           0.80       148
#    macro avg       0.80      0.80      0.80       148
# weighted avg       0.80      0.80      0.80       148

# %% [markdown]
# En líneas generales, los resultados son prácticamente iguales al modelo de ensamble alcanzando los mismos valores de f1 para ambas clases, pero con una caída apenas algo mayor en todas las métricas entre ambos conjuntos. Es decir, la generalización podría ser ligeramente menor, aunque casi imperceptible.
#
# Vamos a estudiar si la optimización del umbral aporta mejoras en la clasificación.

# %%
# Obtenemos el umbral y graficamos su evolución
xg_best_threshold, xg_metrics = afn.viz_threshold_behavior(xg_model, X_val, y_val, num_thresholds=30)
probs_xg = y_pred_xg[:, 1]
y_pred_proba_xg = (probs_xg >= xg_best_threshold)
xg_metrics['model'] = 'XGBoost'

# %%
print(classification_report(y_val, y_pred_proba_xg))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.82      0.81        71
#          1.0       0.83      0.81      0.82        77
#
#     accuracy                           0.81       148
#    macro avg       0.81      0.81      0.81       148
# weighted avg       0.81      0.81      0.81       148

# %% [markdown]
# La optimización del umbral tiene poco margen de maniobra y las mejoras aportadas son apenas perceptibles, ya que todas las métricas presentan variaciones máximas de un 1%. Podemos conjeturar que no hay mayores cambios que unas pocas observaciones. De hecho, la curva de roc es prácticamente la misma, con apenas un aumento de 0,003 con respecto a Random Forest.
#
# Vamos a visualizarlo mediante la matriz de confusión.

# %%
afn.viz_confusion_matrix_thres(labels, y_val, y_pred_val_xg, y_pred_proba_xg)

# %% [markdown]
# Efectivamente, comprobamos que el modelo hace su mejor clasificación de la clase mejorable sin necesidad de ajustes posteriores. El único cambio es una mejoría en la clasificación de la clase aceptable casi imperceptible en la cantidad de observaciones que contienen el conjunto de validación.
#
# Vamos a observar este límite en la mejora con la visualización del umbral y las probabilidades.

# %%
afn.viz_threshold_optimization(probs_xg, y_val, y_pred_proba_xg, xg_best_threshold)

# %% [markdown]
# En este caso, existen más observaciones de la clase mejorable con menor probabilidad asignada (se encuentran más dispersas hacia la izquierda) que en el modelo anterior. Es posible que este límite en la diferenciación de las clases se deba a la complejidad del conjunto de datos y sus características.

# %% [markdown]
# ### 2.4 CatBoost

# %%
# Repetimos el flujo de trabajo para el modelo
cb_parameters = {
    'depth': [3, 5, 7],
    'iterations': [200, 250, 300],
    'learning_rate': [0.05, 0.06],
    'l2_leaf_reg': [3, 4, 5],
    'bagging_temperature': [0, 1],
    'rsm': [0.5, 1.0],
    'leaf_estimation_iterations': [5, 10, 15]
}
cb_model = CatBoostClassifier(
    loss_function='Logloss', 
    eval_metric='Logloss', 
    random_state=73,
    early_stopping_rounds=50,
    verbose=False
)
cb_grid = GridSearchCV(
    estimator=cb_model,
    param_grid=cb_parameters,
    scoring='f1_macro',
    cv=5,
    n_jobs=-1
)
# %time cb_grid.fit(X_train, y_train)

print('Media de F1 score: %.3f' % cb_grid.best_score_)
print('Desviación estándar: ', cb_grid.cv_results_['std_test_score'][cb_grid.best_index_].round(3))
print('Parámetros que producen el clasificador óptimo: ')
print('Profundidad: ', cb_grid.best_params_['depth'])
print('Tasa de aprendizaje: ', cb_grid.best_params_['learning_rate'])
print('Regularización en hojas: ', cb_grid.best_params_['l2_leaf_reg'])
print('Muestreo aleatorio: ', cb_grid.best_params_['bagging_temperature'])
print('Porcentaje de variables utilizado: ', cb_grid.best_params_['rsm'])
print('Número de árboles: ', cb_grid.best_params_['iterations'])
print('Iteraciones estimadas de las hojas: ', cb_grid.best_params_['leaf_estimation_iterations'])
# Out:
# CPU times: user 2.17 s, sys: 718 ms, total: 2.89 s
# Wall time: 1min 19s
# Media de F1 score: 0.815
# Desviación estándar:  0.025
# Parámetros que producen el clasificador óptimo:
# Profundidad:  3
# Tasa de aprendizaje:  0.06
# Regularización en hojas:  4
# Muestreo aleatorio:  0
# Porcentaje de variables utilizado:  1.0
# Número de árboles:  250
# Iteraciones estimadas de las hojas:  10

# %% [markdown]
# Para el algoritmo CatBoost el modelo encntrado en el espacio de hiperparametros presenta mayor cantidad de árboles que en los casos anteriores, aunque con menor profundidad. La tasa de aprendizaje relativamente baja (0.06) indica que el modelo realiza actualizaciones suaves en cada iteración, lo que mejora la generalización y es coherente con el alto número de árboles. La regularización aplicada en las hojas (4) y la ausencia de muestreo aleatorio (0%) reflejan una preferencia por utilizar todos los datos en cada iteración, lo que, junto con el uso del 100% de las variables en cada split, maximiza la información considerada para cada división.
#
# El resultado de F1-score medio de 0.815 con una desviación estándar moderada (0.025) indica un buen rendimiento general y estabilidad en las predicciones del modelo a lo largo de las distintas particiones de validación cruzada, en la misma línea que XGBoost.
#
# Continuamos con el análisis del mejor modelo encontrado.

# %%
# Obtenemos las probabilidades del mejor modelo y graficamos los resultados
cb_model = cb_grid.best_estimator_
cb_model.fit(X_train, y_train)
y_pred_cb = cb_model.predict_proba(X_val)
y_pred_train_cb, y_pred_val_cb, cb_report = afn.viz_classification_reports(cb_model, X_train, y_train, X_val, y_val)
# Out:
# Reporte sobre el conjunto de ENTRENAMIENTO:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.89      0.86       422
#          1.0       0.89      0.83      0.86       462
#
#     accuracy                           0.86       884
#    macro avg       0.86      0.86      0.86       884
# weighted avg       0.86      0.86      0.86       884
#
# Reporte sobre el conjunto de validation:  VALIDATION
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.82      0.81        71
#          1.0       0.83      0.81      0.82        77
#
#     accuracy                           0.81       148
#    macro avg       0.81      0.81      0.81       148
# weighted avg       0.81      0.81      0.81       148

# %% [markdown]
# Encontramos que el modelo CatBoost obtiene exactamente las mismas métricas que XGBoost para el conjunto de validación, a pesar de que presenta alguna leve mejora en el entrenamiento. Efectivamente, el F1 score continúa siendo 0.81 y 0.82 para la clase 0 y 1 respectivamente.
#
# A continuación, analizamos si el ajuste del umbral aporta alguna mejora a la clasificación.

# %%
# Calculamos el umbral de decisión óptimo
cb_best_threshold, cb_metrics = afn.viz_threshold_behavior(cb_model, X_val, y_val, num_thresholds=25)
probs_cb = y_pred_cb[:, 1]
y_pred_proba_cb = (probs_cb >= cb_best_threshold)
cb_metrics['model'] = 'CatBoost'

# %%
print(classification_report(y_val, y_pred_proba_cb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.82      0.81        71
#          1.0       0.83      0.82      0.82        77
#
#     accuracy                           0.82       148
#    macro avg       0.82      0.82      0.82       148
# weighted avg       0.82      0.82      0.82       148

# %% [markdown]
# Confirmamos que el comportamiento es idéntico a XGBoost obteniendo las mismas métricas con variaciones prácticamente imperceptibles.

# %%
afn.viz_confusion_matrix_thres(labels, y_val, y_pred_val_cb, y_pred_proba_cb)

# %% [markdown]
# La matriz de confusión reafirma las conclusiones anteriores y vemos como el presente modelo genera un falso negativo menos aumentando la precisión de los verdaderos positivos para la clase 1. En definitiva, ambos modelos parecen alcanzar el mismo límite en la capacidad de diferenciación de ambas clases.

# %%
afn.viz_threshold_optimization(probs_cb, y_val, y_pred_proba_cb, cb_best_threshold)

# %% [markdown]
# En cuanto al umbral de decisión, encontramos que el costo de forzar una mejora muy leve en los verdaderos positivos tiene un coste mayor en la cantidad de falsos positivos que se generarían.

# %% [markdown]
# ### 2.5 Light Gradient-Boosting Machine (LigthGBM)

# %%
lg_parameters = {
    'n_estimators': [150],          
    'learning_rate': [0.07],        
    'max_depth': [6, 8],              
    'num_leaves': [4],             
    'min_child_samples': [4],      
    'reg_alpha': [0.1],            
    'reg_lambda': [0.009],                      
    'min_split_gain': [0.09]                   
}

lg_model = LGBMClassifier(
    objective='binary', 
    boosting_type='gbdt', 
    random_state=73, 
    verbose=0,
)

lg_grid = GridSearchCV(
    estimator=lg_model, 
    param_grid=lg_parameters, 
    scoring='f1_macro', 
    cv=5,
    n_jobs=-1,
)
X_train.columns = X_train.columns.str.replace(' ', '_')
X_test.columns = X_test.columns.str.replace(' ', '_')
X_val.columns = X_val.columns.str.replace(' ', '_')
# %time lg_grid.fit(X_train, y_train)

print('Media de F1 score: %.3f' % lg_grid.best_score_)
print('Desviación estándar: ', lg_grid.cv_results_['std_test_score'][lg_grid.best_index_].round(3))
print('Parámetros que producen el clasificador óptimo: ')
print('Mínimo de árboles', lg_grid.best_params_['n_estimators'])
print('Profundidad: ', lg_grid.best_params_['max_depth'])
print('Tasa de aprendizaje: ', lg_grid.best_params_['learning_rate'])
print('Número de leaves: ', lg_grid.best_params_['num_leaves'])
print('Mínimo de muestras', lg_grid.best_params_['min_child_samples'])
print('Alpha', lg_grid.best_params_['reg_alpha'])
print('Lambda', lg_grid.best_params_['reg_lambda'])
print('Mínimo de ganancia', lg_grid.best_params_['min_split_gain'])
# Out:
# CPU times: user 499 ms, sys: 180 ms, total: 679 ms
# Wall time: 1.89 s
# Media de F1 score: 0.804
# Desviación estándar:  0.033
# Parámetros que producen el clasificador óptimo:
# Mínimo de árboles 150
# Profundidad:  6
# Tasa de aprendizaje:  0.07
# Número de leaves:  4
# Mínimo de muestras 4
# Alpha 0.1
# Lambda 0.009
# Mínimo de ganancia 0.09

# %% [markdown]
# El modelo óptimo de LightGBM obtenido se compone de un mínimo de 150 árboles, con una profundidad máxima de 6 niveles y solo 4 hojas por árbol, lo que sugiere una estructura deliberadamente simple, orientada a limitar divisiones innecesarias.
#
# La tasa de aprendizaje utilizada fue de 0.07, un valor moderado que permite converger rápidamente sin saltos excesivos. En cuanto a regularización, se aplicaron valores bajos, pero no nulos tanto en alpha (0.1) como en lambda (0.009), lo que introduce una penalización leve que ayuda a mejorar la capacidad de generalización del modelo. También se estableció un umbral mínimo de ganancia de 0.09 para realizar splits, lo que impone una exigencia adicional a la hora de dividir nodos.
#
# A nivel de rendimiento, el modelo alcanzó una media de f1-score de 0.804, con una desviación estándar de 0.033. Una vez más, indica un desempeño competitivo y estable en los distintos pliegues de validación cruzada, con una leve caída respecto a los modelos anteriores.

# %%
# Entrenamos el mejor estimador
lg_model = lg_grid.best_estimator_
lg_model.fit(X_train, y_train)
y_pred_lg = lg_model.predict_proba(X_val)

# %%
y_pred_train_lg, y_pred_val_lg, lg_report = afn.viz_classification_reports(lg_model, X_train, y_train, X_val, y_val)
# Out:
# Reporte sobre el conjunto de ENTRENAMIENTO:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.88      0.85       422
#          1.0       0.88      0.82      0.85       462
#
#     accuracy                           0.85       884
#    macro avg       0.85      0.85      0.85       884
# weighted avg       0.85      0.85      0.85       884
#
# Reporte sobre el conjunto de validation:  VALIDATION
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.80      0.80        71
#          1.0       0.82      0.81      0.81        77
#
#     accuracy                           0.80       148
#    macro avg       0.80      0.80      0.80       148
# weighted avg       0.80      0.80      0.80       148

# %% [markdown]
# El modelo se comporta de forma similar a Random Forest, obteniendo el resultado en todas las métricas. En el conjunto de validación, el rendimiento se mantiene alto, con una media ponderada de f1-score de 0.80. Ambas clases muestran métricas similares, lo que evidencia una buena generalización: la clase aceptable tiene un f1-score de 0.80, mientras que la clase mejorable llega a 0.81. La caída moderada respecto al entrenamiento es esperada y refleja un comportamiento saludable del modelo frente a datos no vistos.
#
# Los gráficos de precisión, recall y f1-score por clase muestran caídas proporcionales entre ambos conjuntos, confirmando que el modelo no está sobreajustado y que su desempeño es consistente.

# %%
# Analizamos el umbral de decisión
lg_best_threshold, lg_metrics = afn.viz_threshold_behavior(lg_model, X_val, y_val, num_thresholds=25)
probs_lg = y_pred_lg[:, 1]
y_pred_proba_lg = (probs_lg >= lg_best_threshold)
lg_metrics['model'] = 'LGB Machine'

# %%
print(classification_report(y_val, y_pred_proba_lg))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.77      0.80        71
#          1.0       0.80      0.84      0.82        77
#
#     accuracy                           0.81       148
#    macro avg       0.81      0.81      0.81       148
# weighted avg       0.81      0.81      0.81       148

# %% [markdown]
# El área bajo la curva es la misma que en el modelo Random Forest, y las métricas obtenidas con el umbral ajustado también son muy similares. Podemos concluir que el modelo aporta mejoras mínimas respecto a Random Foresta a cargo de su mayor complejidad y costo computacional.

# %%
afn.viz_confusion_matrix_thres(labels, y_val, y_pred_val_lg, y_pred_proba_lg)

# %% [markdown]
# La matriz de confusión confirma nuevamnete que el modelo es capaz de realizar una clasificación muy cercana a su mejor capacidad con el umbral ajustado. Como era de esperar los resultados son muy similares al modelo de ensamble, aunque con una mejora apenas perceptible en los falsos negativos.

# %%
afn.viz_threshold_optimization(probs_lg, y_val, y_pred_proba_lg, lg_best_threshold)

# %% [markdown]
# En este caso, el umbral de decisión se ve claramente limitado por los verdaderos positivos.

# %%
# Reestablecemos los nombres de las variables
X_train.columns = X_train.columns.str.replace('_', ' ')
X_test.columns = X_test.columns.str.replace('_', ' ')
X_val.columns = X_val.columns.str.replace('_', ' ')

# %% [markdown]
# ### Comparación de los modelos
#
# Todos los modelos han arrojado resultados muy similares, sin diferencias significativas a la hora de clasificar ambas clases. A continuación estudiaremos los resultados comparativamente para análizar más en profundidad estas pequeñas diferencias. Para ello, vamos a graficar las métricas obtenidas para cada uno de los modelos.

# %%
# Generamos un df con todas las métricas que hemos ido recolectando durtante el entrenamiento de cada modelo
all_metrics = pd.concat([dt_metrics, rf_metrics, xg_metrics, cb_metrics, lg_metrics], ignore_index=True)
melted = all_metrics.melt(id_vars='model', value_vars=['Accuracy', 'Precision', 'Recall', 'F1-score'], var_name='Metric', value_name='Score')
# Graficamos los resultados 
plt.figure(figsize=(10, 6))
sns.barplot(data=melted, x='model', y='Score', hue='Metric')
plt.title('Comparativa de métricas en el umbral óptimo por modelo', y=1.02)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1), ncol=4, fontsize=12)
plt.ylim(0, 1)
plt.grid(True, axis='y')
plt.tight_layout()
sns.despine(left=True)
plt.show()

# %% [markdown]
# Como era de esperar, encontramos una paridad muy alta en todos los modelos con Decision Tree destacando en precisión. En cuanto a F1 score y recall, CatBoost y LGBM obtienen las mismas prestaciones. Sin embargo, como hemos visto LGBM tiene una muy leve mejora en cuanto a la clasificación de la clase 1.
#
# Vamos a probar ambos modelos con el conjunto de test para analizar los resultados y tomar una decisión definitiva. Comenzamos por el Random Forest:

# %%
# Instanciamos el modelo nuevamente para resetear el entrenamiento y predecir el conjunto de prueba
rf_model_test = RandomForestClassifier(
    random_state = 73,
    n_jobs=-1,
    **rf_grid.best_params_
)
rf_model_test.fit(X_train, y_train)
y_pred_train_rf_test, y_pred_rf_test, rf_model_test_report = afn.viz_classification_reports(rf_model_test, X_train, y_train, X_test, y_test, 'prueba')
# Out:
# Reporte sobre el conjunto de ENTRENAMIENTO:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.90      0.87       422
#          1.0       0.90      0.84      0.87       462
#
#     accuracy                           0.87       884
#    macro avg       0.87      0.87      0.87       884
# weighted avg       0.87      0.87      0.87       884
#
# Reporte sobre el conjunto de prueba:  PRUEBA
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.79      0.77       141
#          1.0       0.80      0.75      0.78       154
#
#     accuracy                           0.77       295
#    macro avg       0.77      0.77      0.77       295
# weighted avg       0.77      0.77      0.77       295

# %% [markdown]
# Los resultados obtenidos en el conjunto de prueba muestran una ligera caída respecto al entrenamiento, con una accuracy global del 77% y un f1-score macro de 0.77, frente al 87% en ambos casos durante el entrenamiento. Aunque la diferencia es más pronunciada que la observada en la fase de validación, el descenso es proporcional y simétrico entre las dos clases, lo que indica que el modelo generaliza correctamente sin señales de sobreajuste.
#
# El modelo mantiene un rendimiento equilibrado, con métricas similares en precisión y recall para ambas clases también en test (f1-score ≈ 0.77–0.78), lo que refuerza su robustez. Esta pérdida controlada de rendimiento es esperable al enfrentarse a datos completamente nuevos, y valida la eficacia del proceso de validación cruzada.

# %%
rf_test_best_threshold, rf_best_best_metrics = afn.viz_threshold_behavior(rf_model_test, X_test, y_test, num_thresholds=25)

# %% [markdown]
# El análisis del comportamiento del modelo sobre el conjunto de prueba muestra un valor de AUC-ROC de 0.855, ligeramente superior al obtenido en validación, lo que confirma la capacidad discriminativa del modelo frente a datos no vistos. El umbral óptimo, situado en 0.426, aparece algo más desplazado hacia la izquierda respecto a los modelos anteriores. Esta posición refleja una estrategia más conservadora: clasificar como “mejorable” incluso casos con menor probabilidad estimada, lo que incrementa la sensibilidad a costa de aceptar un mayor número de falsos positivos.

# %%
probs_rf_test = rf_model_test.predict_proba(X_test)[:, 1]
y_pred_proba_rf_test = (probs_rf_test >= rf_test_best_threshold)
afn.viz_confusion_matrix_thres(labels, y_test, y_pred_rf_test, y_pred_proba_rf_test)

# %% [markdown]
# La matriz de confusión ajustada confirma el aumento de falsos positivos (FP) como consecuencia del ajuste del umbral, lo que constituye el coste previsible de mejorar la sensibilidad hacia la clase mejorable. El número de verdaderos positivos (TP) aumenta de 116 a 128, y los falsos negativos (FN) se reducen a 26, lo que representa una mejora significativa en la identificación de pacientes con calidad de vida mejorable. Esta ganancia se compensa con un incremento de los falsos positivos de 29 a 41, que representa aproximadamente un 10% adicional dentro de los casos aceptables.

# %%
afn.viz_threshold_optimization(probs_rf_test, y_test, y_pred_proba_rf_test, rf_test_best_threshold)

# %% [markdown]
# El ajuste del umbral demuestra con claridad la «negociación» inherente al proceso de optimización: al reducir el umbral a 0.426, el modelo logra detectar un mayor número de verdaderos positivos (TP), pero a costa de incrementar notablemente los falsos positivos (FP). Esta compensación es evidente en la distribución de errores a ambos lados del umbral, que nos permite estimar dinámicamente la matriz de confusión desplazando el umbral de decisión. Es decir, podemos identificar con claridad cómo se desplazan los errores en función del umbral y ofrecer una herramienta clave para decidir, en función del contexto clínico, si priorizar sensibilidad o especificidad.
#
# Vamos a analizar el comportamiento del clasificador LGBM con el conjunto de prueba.

# %%
lg_model_test = LGBMClassifier(
    objective='binary',
    boosting_type='gbdt',
    random_state=73,
    verbose=0,
    **lg_grid.best_params_
)
lg_model_test.fit(X_train, y_train)
y_pred_train_lg_test, y_pred_lg_test, lg_model_test_report = afn.viz_classification_reports(lg_model_test, X_train, y_train, X_test, y_test, 'prueba')
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# Reporte sobre el conjunto de ENTRENAMIENTO:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.88      0.85       422
#          1.0       0.88      0.82      0.85       462
#
#     accuracy                           0.85       884
#    macro avg       0.85      0.85      0.85       884
# weighted avg       0.85      0.85      0.85       884
#
# Reporte sobre el conjunto de prueba:  PRUEBA
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.81      0.77       141
#          1.0       0.81      0.74      0.77       154
#
#     accuracy                           0.77       295
#    macro avg       0.77      0.77      0.77       295
# weighted avg       0.78      0.77      0.77       295

# %% [markdown]
# Como era de esperar, el modelo de LightGBM presenta un rendimiento final muy similar al de Random Forest, sin cambios significativos. En el conjunto de prueba, alcanza un f1-score medio de 0.77, manteniendo la simetría entre clases.

# %%
lg_test_best_threshold, lg_best_best_metrics = afn.viz_threshold_behavior(lg_model_test, X_test, y_test,
                                                                           num_thresholds=25)

# %% [markdown]
# Tampoco se observan cambios significativos en el valor de ROC AUC, que se mantiene elevado en 0.845, lo que confirma la buena capacidad discriminativa del modelo. Sin embargo, en este caso el umbral óptimo se desplaza hacia la derecha (0.564), indicando que el modelo requiere una mayor probabilidad estimada para clasificar un caso como mejorable. Este ajuste sugiere una estrategia algo más conservadora, que prioriza la reducción de falsos positivos a cambio de aceptar un ligero descenso en la sensibilidad, obtendrá mayor cantidad de falsos negativos.

# %%
probs_lg_test = lg_model_test.predict_proba(X_test)[:, 1]
y_pred_proba_lg_test = (probs_lg_test >= lg_test_best_threshold)
afn.viz_confusion_matrix_thres(labels, y_test, y_pred_lg_test, y_pred_proba_lg_test)

# %% [markdown]
# La matriz ajustada confirma la estrategia conservadora adoptada por el modelo tras el desplazamiento del umbral. Se observa una reducción de falsos positivos (de 27 a 20), lo que implica una mejora en la precisión de la clase aceptable. Sin embargo, este beneficio se acompaña de un aumento de falsos negativos (de 40 a 42), es decir, se pierden algunos casos de calidad de vida mejorable que antes eran detectados. Esta compensación es coherente con el ajuste del umbral hacia la derecha, y responde a una lógica más estricta a la hora de predecir un caso como mejorable.

# %%
afn.viz_threshold_optimization(probs_lg_test, y_test, y_pred_proba_lg_test, lg_test_best_threshold)

# %% [markdown]
# Finalmente, la visualización de errores por umbral confirma el efecto del ajuste observado previamente: el modelo aplica un umbral más exigente (0.564), lo que se traduce en una clasificación más conservadora. Esto se refleja en una clara reducción de falsos positivos (FP) —casos aceptables mal clasificados como mejorables—, a costa de un ligero aumento de falsos negativos (FN).

# %% [markdown]
# ## 3. Conclusiones

# %% [markdown]
# Se han entrenado y evaluado cinco modelos: Decision Tree, Random Forest, XGBoost, CatBoost y LightGBM, utilizando validación cruzada estratificada y optimización de hiperparámetros mediante GridSearchCV. Además, se ha aplicado un ajuste fino del umbral de decisión con el objetivo de maximizar la métrica f1-score, buscando un equilibrio entre sensibilidad y precisión. Este enfoque ha demostrado ser especialmente útil para controlar los errores tipo II (falsos negativos), priorizando la detección de pacientes con QoL mejorable.
#
# Los modelos evaluados han mostrado un rendimiento muy similar entre sí, con f1-score promedio en el conjunto de prueba en torno al 0.77–0.78. LightGBM y Random Forest han ofrecido el mejor equilibrio entre rendimiento y estabilidad, con valores altos de AUC-ROC, simetría entre clases y mínima pérdida entre entrenamiento y test.
#
# La visualización de errores por probabilidad y las matrices de confusión ajustadas han aportado información valiosa para interpretar el comportamiento limítrofe de los modelos. Se ha evidenciado que la mayor parte de los errores se concentran en torno al umbral óptimo, lo que refuerza la utilidad del ajuste manual y visual para cada clasificador.
#
# En conjunto, se concluye que la clasificación binaria desarrollada presenta un rendimiento sólido, aunque no se puede considerar óptima en cuanto la cantidad de errores que definitivamente presentan todos los modelos. Es probable que la complejidad del conjunto de datos no permita superar el límite de clasificación alcanzado —muy similar en todos los modelos— y sea necesario enriquecer el conjunto con nuevas observaciones para estudiar posibles mejoras en el tratamiento.
#
# En cuanto al modelo óptimo a seleccionar, el algoritmo Random Forest ha demostrado una mejor capacidad para clasificar correctamente la clase mejorable, alineándose con los objetivos del presente trabajo. Además, su simplicidad y bajo coste computacional lo posicionan como una opción preferente frente a modelos más complejos, como los algoritmos de *Boosting*, que no han aportado mejoras significativas.

# %% [markdown]
# ## 4. Exportación del modelo seleccionado y los datos

# %%
bundle = {
    'model': rf_model_test,
    'threshold': rf_test_best_threshold
}
joblib.dump(bundle, './models/best_bundle.pkl')
# Out:
# ['./models/best_bundle.pkl']

# %%
X_cal.to_csv('./data/QLQ_C30_C23_X_cal.csv', index=False)
y_cal.to_csv('./data/QLQ_C30_C23_y_cal.csv', index=False)
X_train.to_csv('./data/QLQ_C30_C23_X_train.csv', index=False)
X_test.to_csv('./data/QLQ_C30_C23_X_test.csv', index=False)
y_train.to_csv('./data/QLQ_C30_C23_y_train.csv', index=False)
y_test.to_csv('./data/QLQ_C30_C23_y_test.csv', index=False)

# %% [markdown]
# ## 4. Bibliografía

# %% [markdown]
# [1] Pimàs, Pablo. (2025). 1_EDA.ipynb [notebook en línea]. Repositorio: TFG - Inteligencia Artificial. GitHub. [Fecha de consulta: 14 de abril de 2025]. https://github.com/ppimas-uoc/TFG---Inteligencia-Artificial/blob/main/Fase%202/1_EDA.ipynb
#
# [2] Pimàs, Pablo. (2025). 2.2_Modelado_multiclase.ipynb [notebook en línea]. Repositorio: TFG - Inteligencia Artificial. GitHub. [Fecha de consulta: 14 de abril de 2025]. https://github.com/ppimas-uoc/TFG---Inteligencia-Artificial/blob/main/Fase%202/2.2_Modelado_multiclase.ipynb
